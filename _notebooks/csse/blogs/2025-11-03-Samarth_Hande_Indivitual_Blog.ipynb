# %% [raw]
# ---
# layout: post
# toc: True
# title: Samarth Hande Indivitual Blog
# description: This is my (Samarth Hande's) indivitual blog reflecting on learning this past year.
# permalink: /blogs/SamarthHande
# author: Samarth H
# ---

# %% [markdown]
# # Sprint 1 -- Tools Setup

# %% [markdown]
# # Sprint 2 -- Lesson Review

# %% [markdown]
# # Sprint 3 -- Creating a Game
#
# Our team did an amazing job with our game, and I played a major role in our sucsess. Here are some statistics to show how we did:

# %% [markdown]
# <!-- Paste link to diagram showing damages here -->

# %% [markdown]
# Despite these hinderences, we were able to quickly recover through hard work.
#
# <!-- Continue here with commit stats -->
