# %% [raw]
# ---
# layout: opencs
# toc: True
# codemirror: true
# title: Samarth Hande Individual Blog
# description: This is Samarth Hande's individual blog reflecting on learning this past year.
# permalink: /blogs/SamarthHande
# author: Samarth H
# ---

# %% [markdown]
# ## Sprint 1 -- Tools Setup
#
# At the begining of the year, I spent my time re-familiarizing myself with basic CS tools.

# %% [markdown]
# ### Challenges with Tools
#
# Often times, my `make` command would break. Thanks to my debbuging experience, I was able to resolve the issue. Here are commands that helped me:

# %%
#!/bin/bash

pip install -r requirements.txt
gem install faraday-retry  # This was the most useful
make stop
make clean
make serve-minema

# %% [markdown]
# ### Quick Breif on How to Setup Tools
#
# Throughout my journey of tools, I learned to setup tools on two operating systems, including Chrome (via Kasm) and Windows.

# %% [markdown]
# #### Kasm
#
# This breif assumes that you have already created a `student` repo. If you have not, fork the [OpenCS Student Repo](https://github.com/Open-Coding-Society/student).
#
# To setup KASM, I ran through the following steps:
#
# 1. Create an account in [OpenCS Pages](https://pages.opencodingsociety.com/login).
# 2. Visit [OpenCS Kasm](https://kasm.opencodingsociety.com/), then login with your credentials.
# 3. Click either `Kali`, or `Ubuntu`. Either will work. Once done, wait for the virtual box to boot up.
# 4. Open a terminal. This is straightforward in Kali. For Ubuntu, click `Application` in the top corner, and then press `Terminal Emulator`.
# 5. Run the following commands, replacing anything inside the `<>` symbols with their required value:

# %%
#!/bin/bash

mkdir -p <YOUR-USERNAME>
git clone https://github.com/<YOUR-USERNAME>/student.git
./scripts/activate.sh  # Enter your Github info
./scripts/venv.sh
venv

# %% [markdown]
# Look at the first command:

# %%
mkdir -p <YOUR-USERNAME>

# %% [markdown]
# The `mkdir` command will create a new directory. In Linux, a set of operating systems that *includes* both Kali and Ubuntu, files and directories are important. You can think of it as a maze. Each of the directories are doors that lead you closer and closer to any given exit. The exits, in this case, are the files.
# Running `mkdir -p <YOUR-USERNAME>` will create a directory with the same name as your Github username. This directory is where you will be able to store all of your Github repo's that are owned by you.

# %%
git clone https://github.com/<YOUR-USERNAME>/student.git

# %% [markdown]
# The `git` command handles operations with Github. `git clone` clones a repository, meaning it brings all the files stored in Github onto your local computer. Now, you can edit your github files, and then commit & sync changes to update on the deployed version!

# %%
./scripts/activate_ubuntu.sh

# %% [markdown]
# The `activate_ubuntu.sh` script is used to activate the Ubuntu environment in the WSL. It takes a bare, empty WSL instance and sets it up with the necessary tools and configurations for development.

# %%
./scripts/activate.sh

# %% [markdown]
# This excecution of the `activate.sh` begins activation of your github enviornment. One critical thing this does is prompt you for your github username and email. Once it has your github credentials, it configs git to use your username and email. This ensures that you get credit for the commits you make. Additionally, the script also configs your system to automatically update your git username and git email every terminal session, so that your git email and username are always used. It does this by modifying the `.bashrc` file, a file that is always run every tty/terminal.

# %%
./scripts/venv.sh

# %% [markdown]
# This execution of `venv.sh` begins setting up your terminal and operating system enviornments. It installs dependencies for your enviornment.

# %%
venv

# %% [markdown]
# This command is aliased to `source venv/bin/activate`. It activates the virtual enviornment.
# Optional: Run `alias venv` to explore how this is aliased.
#
# > **FUN FACT**
# > You can use the `deactivate` command to remove the `(venv)` in front of your terminal prompt, while still having an activated enviornment. This is especially useful when double `(venv)`'s occur.

# %% [markdown]
# ### Hacks
#
# Later on, we moved to hacks. My subteam did the following:
#
# - Calculator
# - Tic Tac Toe
#
# Calculator was done by many people, and I played a major role in the inital development. Tic Tac Toe was done by me. The code for it was in python, my preffered and "natural" coding language. For this reason, I was instrumental in the development in this game. In the tic tac toe terminal, I added color, and extra functionality.<br>
#
# ![Tic Tac Toe Game](https://samarthhande.github.io/portfolio/images/blogs/samarthh/ticTacToe.png)<br>

# %% [markdown]
# ### Closing Thoughts
#
# - This sprint gave me an intro to how the class would be
# - The game went well, with collaboration between me and my teammates
# - This success set the stage for my later sprints to be completed well

# %% [markdown]
# ### Improvement
#
# I could have improved by:
#
# - Spending more time at home to work
# - Establishing better communication with my group
# - Working non-*coding* related skills that are still used in *computer science*
#   - Soft skills
#   - Software Dev. Lifecycle
# - Doing more to recall my js knowlage from back in the day
# - Starting in subteam 2 instad of subteam 1.

# %% [markdown]
# ## Sprint 2 -- Lesson Review
#
# Now we'll look at how I did with lessons, and how I could improve. I'll keep it to just that.

# %% [markdown]
# ### What Went Well
#
# - We made one of the best lessons out of all of them!
# - We communicated and split roles in our subteam
#     - I did the vars lesson
#     - Krish did the popcorn hacks  (with some support from me in terms of the code and file structure)
#     - Pranay did the hw  (with some support from me in terms of the code and file structure)
# - We did a great job helping out those who needed help in our group
# - Other groups knew are lesson was great they used parts of it
#     ![Image showing how other groups used some of our code](https://samarthhande.github.io/portfolio/images/blogs/samarthh/message.png)

# %% [markdown]
# ### What Could Have Improved
#
# - While we did the best job out of all groups in terms of establishing convetions (me for Vars, Anish for Funcs), we still weren't perfect
# - We could have taken more inspiration from other groups and incorperated parts of their lessons that we liked into our lesson

# %% [markdown]
# ### What I learned
#
# - On the technical side, I didn't learn much new stuff, as this was all fundementals
#   - My previous coding background had taught me all of this alreday
# - On the syntax side, I was refreshed
#   - Javascript isn't my primary langauge, it's python
#   - Before this class, I last worked with js in 5th grade
# - On the soft skills side, I learned...  **A LOT**
#   - I learned how to present well
#   - I learned how to present in *groups*
#   - I learned more how to work effectively with others who have differing backgrounds, setting the stage for my sucsesses in Sprint 3.

# %% [markdown]
# ### My Lesson
#
# Here is a picture of my lesson, and another lesson. Notice how other groups used elements of our lesson in their's.<br>
# ![Image showing our lesson](https://samarthhande.github.io/portfolio/images/blogs/samarthh/varsLesson.png)<br>
#
# This shows another lesson that we inspired:
# ![Image showing our lesson](https://samarthhande.github.io/portfolio/images/blogs/samarthh/otherLesson.png)<br>
#
# Notice any of our inspiring?

# %% [markdown]
# ## Sprint 3 -- Creating a Game
#
# Our team (lvl6) did an amazing job with our game, and I played a major role in our sucsess. Here are some statistics to show how we did:

# %% [markdown]
# ### Coding & Commit Stats
#
# - **4** out of the **5** top CSSE student commiters were in our group (since the start of the sprint)<br>
#   ![Commits Per User Showing me + Teammates with high commits](https://samarthhande.github.io/portfolio/images/blogs/samarthh/commitsPerUser.png)<br>
#   The usernames highlighted in yellow are CSSE students not in my level. Green is CSSE students in my level. Blue is me!
# - **2** out of the **3** top commiters in OpenCS pages overall (including CSA and CSP) were in our group (since the start of the sprint)
#     - Only Mr. Mortenson himself had more commits
# - If all of our groups contributions to the game were removed, at total of **0** levels would be operational
# - I had the **2**nd most commits out of everyone (since the start of the sprint), lagging behind only Mr. Mortenson himself
#
# ### Ideation Stats
#
# - We were the group that demonstrated the most *leadership*
# - Many other levels, from 1 to 5, asked us for our code to certian ideas so they could implement them in their own levels
# - We were the first group to implement these ideas, and following our implementations, other groups took our ideas to implement them in their own levels
#     - Audio (later used by lvl1 & lvl4)
#     - Creating our own `mansionLevel6` markdown file so that we could test our level independenlty from the main group (later used by all levels)
#     - Invisible sprites (later used by lvl1 & lvl2)
#     - etc.
# - We were the *only* group to implement these ideas
#     - Boss fight
#     - Custom Collision Detection (not using the game engine)
#     - etc.
#
# > What did *I* do to contribute to this amazing performance?
#
# I'll start with images showing my contribution. Blue means I added the sprite, green means I made significant contribution, yellow means I made medium contribution, and red means I made contribution to whichever part(s) of the game I circled. By created, I mean first implemented in code.<br>
# ![First Contribution Level](https://samarthhande.github.io/portfolio/images/blogs/samarthh/ContributionToLvlPrt2.png)<br>
# ![Seccoond Contribution Level](https://samarthhande.github.io/portfolio/images/blogs/samarthh/ContributionToLvlPrt1.png)<br>
#
# I played a great role in leadership for our team, making charts showing our commits overall and contribution to the team. This motivated team members into contributing more, leading to our amazing commit statistics.
#
# Below are some of the charts I made:
#
# 1. First chart ever made (earlier in the dev process)<br>
#    ![First Commit Chart](https://samarthhande.github.io/portfolio/images/blogs/samarthh/firstCommitChart.png)<br>
#    Notice how some members were commiting very often, while others were lacking contribution to the code of the game.
# 2. First chart where nobody had more than 50% of commits<br>
#    ![Commit Chart Showing Work Was Not Hogged](https://samarthhande.github.io/portfolio/images/blogs/samarthh/middleCommitChart.png)<br>
#    Now, thanks to my chart making and constant reminding/pestering of my teammates, those who are commiting too often have started to give other some chance, and those who have commited too little or not at all have upped their game.
# 3. Final chart<br>
#    ![Final Commit Chart](https://samarthhande.github.io/portfolio/images/blogs/samarthh/finalCommitChart.png)<br>
#    We can see a continuation in the previous pattern.

# %% [markdown]
# ## Analytics
#
# - Rather than showing you in a photo, I'll show you live
# - Let's visit the [OpenCS dashboard](https://pages.opencodingsociety.com/dashboard)
# - Note that the count is very much lower than my actual contribution, as it only takes into account repo's that aren't forked from another

# %% [markdown]
# ## Overall Reflection of CSSE1
#
# - I got off to a slow start (at least compared to what I was capable of), but I drastically increased as I realized my potential
# - I could have improved by...
#   - Letting Mr. Mortenson know all of my contributions
#   - Spending more time on ideation and planning
#
# ### How I improved
#
# - On the technical side, I was already very good when I came to this class
# - I was also mostly fine with the tools (Kasm, Git, Vscode, etc.), but I did learn some stuff
# - I learned the **MOST** in terms of soft skills such as presenting, and ideation and development processes such as the agile sprint and the software dev. lifecycle (SDLC)
#
# Essentially:
#
# - I thought I wouldn't learn much in the class, and it would just be a basic introduction to the CS pathway at school.
# - I was wrong. There was still more for me to learn.

# %% [markdown]
# ## Sprint 4 -- Ideating, Tinkering, OOP
#
# - In this sprint, I showcased my ability to ideate, tinker, and implement OOP principles in a game my team and I created.
# - I was responsible for `GameLevelFortress`, the last level of our game.
#
# Each Programming Concept Demonstrated is shown below.

# %% [markdown]
# ### Iteration
#
# {% capture code_iteration %}
# // For loop example
# for (let i = 0; i < 5; i++) {
#     console.log("Iteration " + i);
# }
#
# // While loop example
# let count = 0;
# while (count < 3) {
#     console.log("While loop count: " + count);
#     count++;
# }
#
# // For...of loop with array
# const fruits = ["apple", "banana", "orange"];
# for (const fruit of fruits) {
#     console.log("Fruit: " + fruit);
# }
# {% endcapture %}
#
# {% include code-runner.html
#    runner_id="iteration_exercise"
#    language="javascript"
#    code=code_iteration
# %}

# %% [markdown]
# ### Iteration
#
# {% capture code_iteration %}
# // Game Level 6 Fortress - Iteration through game objects
# const gameObjects = ['Player', 'Reaper Boss', 'Scythe Projectile', 'Arrow', 'Fireball'];
# console.log("Fortress Game Objects:");
# for (let i = 0; i < gameObjects.length; i++) {
#     console.log(`Object ${i + 1}: ${gameObjects[i]}`);
# }
#
# // Simulating boss attack patterns with while loop
# let bossHealth = 100;
# let attackCount = 0;
# console.log("\nBoss Attack Sequence:");
# while (bossHealth > 0 && attackCount < 10) {
#     attackCount++;
#     const damage = Math.floor(Math.random() * 15) + 5; // 5-20 damage
#     bossHealth -= damage;
#     console.log(`Attack ${attackCount}: Dealt ${damage} damage, Boss health: ${bossHealth}`);
# }
#
# // For...of loop with scythe trajectory points
# const scytheTrajectory = [
#     {x: 100, y: 200, phase: "launch"},
#     {x: 150, y: 180, phase: "arc"},
#     {x: 200, y: 160, phase: "peak"},
#     {x: 250, y: 180, phase: "return"},
#     {x: 300, y: 200, phase: "impact"}
# ];
#
# console.log("\nScythe Trajectory:");
# for (const point of scytheTrajectory) {
#     console.log(`Position (${point.x}, ${point.y}) - Phase: ${point.phase}`);
# }
#
# // Iterating through boss stages
# const bossStages = ["intro", "stage1", "stage2", "stage3", "final"];
# console.log("\nBoss Battle Stages:");
# for (const stage of bossStages) {
#     console.log(`Entering ${stage.toUpperCase()} stage`);
# }
# {% endcapture %}
#
# {% include code-runner.html
#    runner_id="iteration_exercise"
#    language="javascript"
#    code=code_iteration
# %}

# %% [markdown]
# ### Conditionals
#
# {% capture code_conditionals %}
# // Fortress Level 6 - Player health and game state
# let playerHealth = 85;
# let bossStage = 2;
# let hasScythe = true;
#
# if (playerHealth >= 80) {
#     console.log("Player health is good - ready for boss battle!");
# } else if (playerHealth >= 50) {
#     console.log("Player health is moderate - be careful!");
# } else {
#     console.log("Player health is critical - heal or retreat!");
# }
#
# // Boss stage progression
# if (bossStage === 1) {
#     console.log("Boss Stage 1: Basic attacks only");
# } else if (bossStage === 2) {
#     console.log("Boss Stage 2: Arrow and fireball attacks");
# } else if (bossStage === 3) {
#     console.log("Boss Stage 3: Enhanced attacks + scythe");
# } else {
#     console.log("Final Stage: Maximum boss power!");
# }
#
# // Weapon availability check
# if (hasScythe) {
#     console.log("Scythe weapon unlocked - elliptical attack pattern available!");
# } else {
#     console.log("Basic attacks only - collect scythe to unlock special moves");
# }
#
# // Switch statement for projectile types
# let projectileType = "scythe";
# switch (projectileType) {
#     case "arrow":
#         console.log("Arrow: Straight line projectile, 10 damage");
#         break;
#     case "fireball":
#         console.log("Fireball: Straight line projectile, 15 damage");
#         break;
#     case "scythe":
#         console.log("Scythe: Elliptical trajectory, 20 damage");
#         break;
#     default:
#         console.log("Unknown projectile type");
# }
#
# // Game state conditions
# let currentRoom = "bossBattleRoom";
# let playerHasKey = false;
#
# if (currentRoom === "introChamber" && !playerHasKey) {
#     console.log("Find the key to proceed!");
# } else if (currentRoom === "bossBattleRoom" && playerHasKey) {
#     console.log("Enter the boss battle!");
# } else if (currentRoom === "bossBattleRoom" && !playerHasKey) {
#     console.log("Need the key to enter boss room!");
# } else {
#     console.log("Explore the fortress!");
# }
# {% endcapture %}
#
# {% include code-runner.html
#    runner_id="conditionals_exercise"
#    language="javascript"
#    code=code_conditionals
# %}

# %% [markdown]
# ### Nested Conditions
#
# {% capture code_nested_conditions %}
# // Fortress Level 6 - Complex game logic with nested conditions
# let playerHealth = 75;
# let bossHealth = 60;
# let playerHasKey = false;
# let currentRoom = "introChamber";
# let hasScythe = true;
#
# // Room access logic
# if (currentRoom === "introChamber") {
#     if (playerHasKey) {
#         if (bossHealth <= 0) {
#             console.log("Victory! You've defeated the boss and can escape!");
#         } else {
#             console.log("Key obtained! Ready for boss battle!");
#         }
#     } else {
#         if (playerHealth >= 50) {
#             console.log("Explore the chamber to find the key!");
#         } else {
#             console.log("Low health! Find healing first!");
#         }
#     }
# } else if (currentRoom === "bossBattleRoom") {
#     if (playerHasKey) {
#         if (bossHealth > 50) {
#             console.log("Boss is healthy - be careful!");
#         } else if (bossHealth > 25) {
#             console.log("Boss is wounded - press the attack!");
#         } else {
#             console.log("Boss is nearly defeated - finish it!");
#         }
#     } else {
#         console.log("Cannot enter boss room without the key!");
#     }
# }
#
# // Combat strategy based on multiple factors
# if (playerHealth > 60) {
#     if (hasScythe) {
#         if (bossHealth > 70) {
#             console.log("Aggressive strategy: Use scythe attacks!");
#         } else {
#             console.log("Balanced strategy: Mix scythe and basic attacks!");
#         }
#     } else {
#         if (bossHealth > 50) {
#             console.log("Defensive strategy: Dodge and counter!");
#         } else {
#             console.log("Standard strategy: Basic attacks only!");
#         }
#     }
# } else {
#     if (hasScythe) {
#         if (bossHealth < 30) {
#             console.log("All-in attack: Use scythe to finish boss!");
#         } else {
#             console.log("Cautious approach: Save scythe for critical moment!");
#         }
#     } else {
#         console.log("Survival mode: Focus on dodging and healing!");
#     }
# }
#
# // Projectile selection logic
# let distanceToBoss = 150;
# let bossStage = 2;
# let playerMana = 40;
#
# if (distanceToBoss < 100) {
#     if (bossStage >= 2) {
#         if (playerMana >= 30) {
#             console.log("Close range high stage: Use scythe elliptical attack!");
#         } else {
#             console.log("Close range low mana: Use basic melee attacks!");
#         }
#     } else {
#         console.log("Close range low stage: Use fireball!");
#     }
# } else {
#     if (playerMana >= 20) {
#         if (bossStage >= 3) {
#             console.log("Long range high stage: Use charged arrow!");
#         } else {
#             console.log("Long range normal: Use regular arrow!");
#         }
#     } else {
#         console.log("Long range no mana: Move closer!");
#     }
# }
# {% endcapture %}
#
# {% include code-runner.html
#    runner_id="nested_conditions_exercise"
#    language="javascript"
#    code=code_nested_conditions
# %}

# %% [markdown]
# ### Data Types
#
# {% capture code_data_types %}
# // Fortress Level 6 - Game data types
# let playerName = "Hero";                    // String
# let playerLevel = 6;                        // Number (integer)
# let playerHealth = 85.5;                    // Number (float)
# let hasBossKey = true;                      // Boolean
# let currentRoom = null;                     // Null (no current room)
# let playerInventory;                        // Undefined (not assigned)
# let weaponId = Symbol("scythe_001");        // Symbol (unique identifier)
# let bossMaxHealth = 9007199254740991n;      // BigInt (for very large health values)
#
# console.log("Player Name:", playerName, "- Type:", typeof playerName);
# console.log("Player Level:", playerLevel, "- Type:", typeof playerLevel);
# console.log("Player Health:", playerHealth, "- Type:", typeof playerHealth);
# console.log("Has Boss Key:", hasBossKey, "- Type:", typeof hasBossKey);
# console.log("Current Room:", currentRoom, "- Type:", typeof currentRoom);
# console.log("Player Inventory:", playerInventory, "- Type:", typeof playerInventory);
# console.log("Weapon ID:", weaponId, "- Type:", typeof weaponId);
# console.log("Boss Max Health:", bossMaxHealth, "- Type:", typeof bossMaxHealth);
#
# // Game state object with mixed data types
# let gameState = {
#     // String values
#     currentLevel: "mansionLevel6",
#     difficulty: "hard",
#     bossName: "The Reaper",
#
#     // Number values
#     playerX: 250.5,
#     playerY: 180.3,
#     bossHealth: 100,
#     playerScore: 15000,
#
#     // Boolean values
#     isPaused: false,
#     hasScythe: true,
#     isBossBattle: true,
#
#     // Array and Object values
#     weapons: ["sword", "bow", "scythe"],
#     position: { x: 100, y: 200 },
#
#     // Null and undefined values
#     lastDeathTime: null,
#     specialMove: undefined
# };
#
# console.log("\nGame State Object:");
# console.log("Current Level:", gameState.currentLevel, typeof gameState.currentLevel);
# console.log("Player Position X:", gameState.playerX, typeof gameState.playerX);
# console.log("Is Boss Battle:", gameState.isBossBattle, typeof gameState.isBossBattle);
# console.log("Weapons Array:", gameState.weapons, typeof gameState.weapons);
# console.log("Position Object:", gameState.position, typeof gameState.position);
# console.log("Last Death Time:", gameState.lastDeathTime, typeof gameState.lastDeathTime);
#
# // Type checking in game logic
# function checkDataType(value, description) {
#     console.log(`\n${description}:`);
#     console.log(`Value: ${value}`);
#     console.log(`Type: ${typeof value}`);
#
#     // Additional type checks
#     if (value === null) {
#         console.log("Special: This is null");
#     } else if (Array.isArray(value)) {
#         console.log("Special: This is an array");
#     } else if (typeof value === 'object' && value !== null) {
#         console.log("Special: This is an object");
#     }
# }
#
# checkDataType("Reaper Boss", "Boss Name");
# checkDataType(100, "Boss Health");
# checkDataType(true, "Boss Active Status");
# checkDataType(["arrow", "fireball", "scythe"], "Boss Attacks");
# checkDataType({x: 300, y: 400}, "Boss Position");
# checkDataType(null, "Respawn Timer");
# checkDataType(undefined, "Bonus Item");
# {% endcapture %}
#
# {% include code-runner.html
#    runner_id="data_types_exercise"
#    language="javascript"
#    code=code_data_types
# %}

# %% [markdown]
# ### Numbers
#
# {% capture code_numbers %}
# // Fortress Level 6 - Game mechanics with numbers
# let playerHealth = 85;
# let bossHealth = 100;
# let playerX = 250.75;
# let playerY = 180.33;
# let scytheDamage = 20;
# let arrowDamage = 10;
# let fireballDamage = 15;
#
# console.log("Player Stats:");
# console.log("Health:", playerHealth);
# console.log("Position X:", playerX);
# console.log("Position Y:", playerY);
#
# // Number methods for game calculations
# let damageMultiplier = 1.5;
# console.log("\nDamage Calculations:");
# console.log("Base Scythe Damage:", scytheDamage);
# console.log("Enhanced Damage:", (scytheDamage * damageMultiplier).toFixed(2));
# console.log("Damage as String:", scytheDamage.toString());
# console.log("Damage with Precision:", damageMultiplier.toPrecision(3));
#
# // Math operations for game physics
# let bossX = 400;
# let bossY = 300;
# let playerX2 = 250;
# let playerY2 = 180;
#
# // Distance calculation using Pythagorean theorem
# let distance = Math.sqrt(Math.pow(bossX - playerX2, 2) + Math.pow(bossY - playerY2, 2));
# console.log("\nDistance to Boss:", distance.toFixed(2));
#
# // Game mechanics with Math functions
# console.log("\nGame Mechanics:");
# console.log("Random Boss Damage:", Math.floor(Math.random() * 20) + 5); // 5-25 damage
# console.log("Critical Hit Chance:", Math.random() < 0.2 ? "CRITICAL!" : "Normal hit");
# console.log("Player Level (rounded up):", Math.ceil(6.3));
# console.log("Boss Stage (rounded down):", Math.floor(2.8));
#
# // Scythe trajectory calculations
# let scytheProgress = 0.785; // radians
# let ellipseWidth = 150;
# let ellipseHeight = 60;
# let scytheX = ellipseWidth * Math.cos(scytheProgress);
# let scytheY = ellipseHeight * Math.sin(scytheProgress);
#
# console.log("\nScythe Trajectory:");
# console.log("Progress (radians):", scytheProgress);
# console.log("X Position:", scytheX.toFixed(2));
# console.log("Y Position:", scytheY.toFixed(2));
#
# // Health and damage calculations
# let maxPlayerHealth = 100;
# let currentHealthPercent = (playerHealth / maxPlayerHealth) * 100;
# console.log("\nHealth Management:");
# console.log("Health Percentage:", currentHealthPercent + "%");
# console.log("Healing Needed:", Math.max(0, maxPlayerHealth - playerHealth));
# console.log("Overheal Amount:", Math.max(0, playerHealth - maxPlayerHealth));
#
# // Number constants in game context
# console.log("\nNumber Constants:");
# console.log("Max Safe Integer:", Number.MAX_SAFE_INTEGER);
# console.log("PI (for circular attacks):", Math.PI);
# console.log("E (for exponential growth):", Math.E);
#
# // Checking valid game values
# let playerScore = 15000;
# let bossTimer = 120;
#
# console.log("\nValue Validation:");
# console.log("Is player score finite?", isFinite(playerScore));
# console.log("Is boss timer finite?", isFinite(bossTimer));
# console.log("Is damage calculation NaN?", isNaN(Math.sqrt(-1)));
#
# // BigInt for large game values
# let totalGameExperience = 9007199254740991n;
# let bonusExperience = 1000000000000n;
# console.log("\nLarge Numbers (BigInt):");
# console.log("Base Experience:", totalGameExperience);
# console.log("Total with Bonus:", totalGameExperience + bonusExperience);
# console.log("Type of BigInt:", typeof totalGameExperience);
# {% endcapture %}
#
# {% include code-runner.html
#    runner_id="numbers_exercise"
#    language="javascript"
#    code=code_numbers
# %}

# %% [markdown]
# ### Strings
#
# {% capture code_strings %}
# // Fortress Level 6 - Game strings and text
# let playerName = "Hero";
# let bossName = "The Reaper";
# let currentLevel = "mansionLevel6";
# let weaponType = "scythe";
#
# console.log("Game Strings:");
# console.log("Player:", playerName);
# console.log("Boss:", bossName);
# console.log("Level:", currentLevel);
# console.log("Weapon:", weaponType);
#
# // String properties and access
# let gameTitle = "Fortress of the Reaper";
# console.log("\nGame Title Analysis:");
# console.log("Title:", gameTitle);
# console.log("Length:", gameTitle.length);
# console.log("First Character:", gameTitle[0]);
# console.log("Last Character:", gameTitle[gameTitle.length - 1]);
#
# // String methods for game messages
# let battleMessage = "The Reaper awaits in the fortress!";
# console.log("\nMessage Manipulation:");
# console.log("Original:", battleMessage);
# console.log("Uppercase:", battleMessage.toUpperCase());
# console.log("Lowercase:", battleMessage.toLowerCase());
# console.log("Character at index 4:", battleMessage.charAt(4));
#
# // Game string searching
# let dialogue = "The Reaper: Your journey ends here! I wield the ultimate scythe!";
# console.log("\nDialogue Analysis:");
# console.log("Full Dialogue:", dialogue);
# console.log("Contains 'Reaper':", dialogue.includes('Reaper'));
# console.log("Position of 'scythe':", dialogue.indexOf('scythe'));
# console.log("Starts with 'The':", dialogue.startsWith('The'));
# console.log("Ends with '!':", dialogue.endsWith('!'));
#
# // Extracting parts of game strings
# console.log("\nString Extraction:");
# console.log("First word:", dialogue.slice(0, dialogue.indexOf(' ')));
# console.log("Boss quote:", dialogue.substring(dialogue.indexOf(':') + 2));
# console.log("Last 10 characters:", dialogue.slice(-10));
#
# // Template literals for game messages
# let playerHealth = 75;
# let bossHealth = 60;
# let currentRoom = "bossBattleRoom";
#
# let statusMessage = `Player: ${playerName} | Health: ${playerHealth}% | Room: ${currentRoom}`;
# let battleStatus = `${bossName} Health: ${bossHealth}% | Weapon: ${weaponType}`;
#
# console.log("\nTemplate Literals:");
# console.log("Player Status:", statusMessage);
# console.log("Battle Status:", battleStatus);
#
# // Game string operations
# let inventory = "sword,shield,potion,scythe,key";
# console.log("\nInventory Management:");
# console.log("Full Inventory:", inventory);
# console.log("Items Array:", inventory.split(','));
# console.log("Joined Back:", inventory.split(',').join(' | '));
#
# // String replacement for game updates
# let oldStatus = "Player is exploring the fortress";
# let newStatus = oldStatus.replace("exploring", "fighting");
# console.log("\nStatus Updates:");
# console.log("Old Status:", oldStatus);
# console.log("New Status:", newStatus);
#
# // String trimming for user input
# let userInput = "   Reaper's Scythe   ";
# console.log("\nUser Input Processing:");
# console.log("Original:", "'" + userInput + "'");
# console.log("Trimmed:", "'" + userInput.trim() + "'");
#
# // String repetition for game effects
# let damageText = "CRITICAL! ";
# console.log("\nDamage Display:");
# console.log("Critical Hit:", damageText.repeat(3));
#
# // Game string comparison
# let weapon1 = "Scythe of Shadows";
# let weapon2 = "scythe of shadows";
# console.log("\nWeapon Comparison:");
# console.log("Exact Match:", weapon1 === weapon2);
# console.log("Case Insensitive:", weapon1.toLowerCase() === weapon2.toLowerCase());
# console.log("Locale Compare:", weapon1.localeCompare(weapon2));
#
# // Practical game string functions
# function formatHealth(health) {
#     return health >= 80 ? "🟢 High" :
#            health >= 50 ? "🟡 Medium" :
#            health >= 20 ? "🟠 Low" : "🔴 Critical";
# }
#
# function getBossTaunt(bossStage) {
#     const taunts = [
#         "You stand no chance!",
#         "The fortress will be your tomb!",
#         "My scythe is hungry!",
#         "Your journey ends now!"
#     ];
#     return taunts[Math.floor(Math.random() * taunts.length)];
# }
#
# console.log("\nGame Functions:");
# console.log("Player Health Status:", formatHealth(playerHealth));
# console.log("Boss Taunt:", getBossTaunt(2));
#
# // String to number conversion for game stats
# let scoreString = "15000";
# let healthString = "85.5";
# console.log("\nString to Number Conversion:");
# console.log("Score as Number:", parseInt(scoreString));
# console.log("Health as Number:", parseFloat(healthString));
# console.log("Converted Score Type:", typeof parseInt(scoreString));
# {% endcapture %}
#
# {% include code-runner.html
#    runner_id="strings_exercise"
#    language="javascript"
#    code=code_strings
# %}

# %% [markdown]
# ### Booleans
#
# {% capture code_booleans %}
# // Fortress Level 6 - Game state booleans
# let isBossBattle = true;
# let hasScythe = true;
# let isPlayerAlive = true;
# let hasKey = false;
# let isPaused = false;
# let canAttack = true;
#
# console.log("Game State Booleans:");
# console.log("Boss Battle Active:", isBossBattle);
# console.log("Has Scythe:", hasScythe);
# console.log("Player Alive:", isPlayerAlive);
# console.log("Has Boss Key:", hasKey);
# console.log("Game Paused:", isPaused);
# console.log("Can Attack:", canAttack);
#
# // Truthy and falsy values in game context
# console.log("\nTruthy/Falsy Game Values:");
# console.log("Player Health (0):", Boolean(0));        // falsy - no health
# console.log("Player Health (100):", Boolean(100));    // truthy - has health
# console.log("Empty Inventory:", Boolean([]));         // truthy - array exists
# console.log("No Weapons:", Boolean(""));              // falsy - empty string
# console.log("No Position:", Boolean(null));           // falsy - no position
# console.log("Undefined Item:", Boolean(undefined));   // falsy - not defined
#
# // Boolean operations for game logic
# let playerHealth = 75;
# let bossHealth = 60;
# let playerHasKey = true;
# let currentRoom = "bossBattleRoom";
#
# console.log("\nGame Logic Operations:");
# console.log("Can Enter Boss Room:", playerHasKey && currentRoom === "bossBattleRoom");
# console.log("Is Battle Over:", playerHealth <= 0 || bossHealth <= 0);
# console.log("Should Heal:", playerHealth < 50 && !isPaused);
# console.log("Can Use Special Attack:", hasScythe && playerHealth > 30);
#
# // Logical operators with game states
# console.log("\nLogical Operators:");
# console.log("Boss Active AND Player Alive:", isBossBattle && isPlayerAlive);
# console.log("Has Scythe OR Has Key:", hasScythe || hasKey);
# console.log("NOT Paused:", !isPaused);
#
# // Boolean expressions for weapon availability
# let weapons = {
#     sword: true,
#     bow: true,
#     scythe: true,
#     magic: false
# };
#
# console.log("\nWeapon Availability:");
# console.log("Can use sword:", weapons.sword);
# console.log("Can use bow:", weapons.bow);
# console.log("Can use scythe:", weapons.scythe);
# console.log("Can use magic:", weapons.magic);
# console.log("Has any weapon:", weapons.sword || weapons.bow || weapons.scythe || weapons.magic);
#
# // Boolean functions for game checks
# function canEnterRoom(roomName, hasRequiredKey, playerIsAlive) {
#     return hasRequiredKey && playerIsAlive;
# }
#
# function shouldUseSpecialAttack(bossStage, playerHealth, hasSpecialWeapon) {
#     return bossStage >= 2 && playerHealth > 40 && hasSpecialWeapon;
# }
#
# function isGameOver(playerHealth, bossHealth, playerHasKey) {
#     return (playerHealth <= 0) || (bossHealth <= 0 && playerHasKey);
# }
#
# console.log("\nGame Check Functions:");
# console.log("Can Enter Boss Room:", canEnterRoom("bossBattleRoom", playerHasKey, isPlayerAlive));
# console.log("Should Use Special Attack:", shouldUseSpecialAttack(2, 75, hasScythe));
# console.log("Is Game Over:", isGameOver(playerHealth, bossHealth, playerHasKey));
#
# // Boolean object (avoid in actual game code)
# let booleanObject = new Boolean(true);
# console.log("\nBoolean Object (avoid using):");
# console.log("Boolean Object:", booleanObject);
# console.log("Type:", typeof booleanObject);
# console.log("Object == true:", booleanObject == true);
# console.log("Object === true:", booleanObject === true);
#
# // Converting game values to booleans
# let gameValues = [0, 1, "", "scythe", [], [1,2,3], {}, null, undefined, false];
# console.log("\nConverting Game Values to Boolean:");
# gameValues.forEach((value, index) => {
#     console.log(`Value ${index}: ${value} -> Boolean: ${Boolean(value)}`);
# });
#
# // Double negation for boolean conversion
# let score = 1500;
# let noScore = 0;
# console.log("\nDouble Negation Conversion:");
# console.log(`Score ${score} -> ${!!score}`);
# console.log(`No Score ${noScore} -> ${!!noScore}`);
#
# // Complex game state boolean
# let gameState = {
#     player: {
#         health: 85,
#         hasScythe: true,
#         isAlive: true,
#         position: { x: 250, y: 180 }
#     },
#     boss: {
#         health: 60,
#         isAlive: true,
#         stage: 2
#     },
#     level: {
#         hasKey: false,
#         isPaused: false,
#         currentRoom: "bossBattleRoom"
#     }
# };
#
# function canPlayerWin(gameState) {
#     return gameState.player.isAlive &&
#            gameState.boss.isAlive &&
#            gameState.player.hasScythe &&
#            gameState.player.health > 30;
# }
#
# console.log("\nComplex Game State:");
# console.log("Can Player Win:", canPlayerWin(gameState));
# console.log("Player in Danger:", gameState.player.health < 50 && gameState.boss.health > 30);
# console.log("Should Use Healing:", gameState.player.health < 40 && !gameState.level.isPaused);
# {% endcapture %}
#
# {% include code-runner.html
#    runner_id="booleans_exercise"
#    language="javascript"
#    code=code_booleans
# %}

# %% [markdown]
# ### Arrays
#
# {% capture code_arrays %}
# // Fortress Level 6 - Game arrays
# let weapons = ["sword", "bow", "scythe", "magic"];
# let bossAttacks = ["arrow", "fireball", "scythe", "melee"];
# let inventory = ["health_potion", "key", "scythe_upgrade"];
# let emptyInventory = [];
#
# console.log("Game Arrays:");
# console.log("Weapons:", weapons);
# console.log("Boss Attacks:", bossAttacks);
# console.log("Inventory:", inventory);
# console.log("Empty Inventory:", emptyInventory);
#
# // Array properties
# console.log("\nArray Properties:");
# console.log("Weapons Length:", weapons.length);
# console.log("First Weapon:", weapons[0]);
# console.log("Last Weapon:", weapons[weapons.length - 1]);
#
# // Array methods - Adding elements
# weapons.push("legendary_sword");
# console.log("\nAfter Push:", weapons);
# weapons.unshift("dagger");
# console.log("After Unshift:", weapons);
#
# // Array methods - Removing elements
# let lastWeapon = weapons.pop();
# console.log("Popped Weapon:", lastWeapon);
# console.log("After Pop:", weapons);
# let firstWeapon = weapons.shift();
# console.log("Shifted Weapon:", firstWeapon);
# console.log("After Shift:", weapons);
#
# // Array methods - Finding elements
# console.log("\nFinding Elements:");
# console.log("Index of 'scythe':", weapons.indexOf('scythe'));
# console.log("Has 'bow':", weapons.includes('bow'));
# console.log("Find weapon with 'scythe':", weapons.find(weapon => weapon.includes('scythe')));
#
# // Array methods - Transforming
# let upperWeapons = weapons.map(weapon => weapon.toUpperCase());
# console.log("Upper Case Weapons:", upperWeapons);
#
# let longWeapons = weapons.filter(weapon => weapon.length > 5);
# console.log("Long Weapon Names:", longWeapons);
#
# let allHaveLetters = weapons.every(weapon => weapon.length >= 2);
# console.log("All have at least 2 letters:", allHaveLetters);
#
# let someHaveScythe = weapons.some(weapon => weapon.includes('scythe'));
# console.log("Some contain 'scythe':", someHaveScythe);
#
# // Array methods - Reducing
# let weaponLengths = weapons.reduce((total, weapon) => total + weapon.length, 0);
# console.log("Total weapon name length:", weaponLengths);
#
# let weaponList = weapons.join(", ");
# console.log("Joined weapons:", weaponList);
#
# // Array methods - Sorting
# let sortedWeapons = [...weapons].sort();
# console.log("Sorted Weapons:", sortedWeapons);
#
# let weaponsByLength = [...weapons].sort((a, b) => a.length - b.length);
# console.log("Weapons by length:", weaponsByLength);
#
# // Array methods - Slicing and splicing
# let someWeapons = weapons.slice(1, 3);
# console.log("Sliced weapons (1, 3):", someWeapons);
#
# let modifiedWeapons = [...weapons];
# modifiedWeapons.splice(1, 1, "crossbow", "staff");
# console.log("Spliced weapons:", modifiedWeapons);
#
# // Multidimensional arrays for game grid
# let gameGrid = [
#     ["wall", "wall", "wall", "wall", "wall"],
#     ["wall", "player", "empty", "key", "wall"],
#     ["wall", "empty", "boss", "empty", "wall"],
#     ["wall", "empty", "empty", "exit", "wall"],
#     ["wall", "wall", "wall", "wall", "wall"]
# ];
#
# console.log("\nGame Grid:");
# console.log("Full Grid:", gameGrid);
# console.log("Player Position:", gameGrid[1][1]);
# console.log("Boss Position:", gameGrid[2][2]);
#
# // Array operations for game mechanics
# function getAvailableWeapons(playerLevel) {
#     const allWeapons = ["sword", "bow", "scythe", "magic", "legendary"];
#     return allWeapons.filter(weapon => {
#         if (weapon === "sword") return playerLevel >= 1;
#         if (weapon === "bow") return playerLevel >= 2;
#         if (weapon === "scythe") return playerLevel >= 3;
#         if (weapon === "magic") return playerLevel >= 4;
#         if (weapon === "legendary") return playerLevel >= 5;
#         return false;
#     });
# }
#
# function getBossAttackPattern(bossStage) {
#     const patterns = {
#         1: ["melee"],
#         2: ["melee", "arrow"],
#         3: ["melee", "arrow", "fireball"],
#         4: ["melee", "arrow", "fireball", "scythe"]
#     };
#     return patterns[bossStage] || ["melee"];
# }
#
# console.log("\nGame Functions:");
# console.log("Available Weapons at Level 3:", getAvailableWeapons(3));
# console.log("Boss Attacks at Stage 2:", getBossAttackPattern(2));
# console.log("Boss Attacks at Stage 4:", getBossAttackPattern(4));
#
# // Array destructuring in game context
# const [mainWeapon, secondaryWeapon, specialWeapon] = weapons;
# console.log("\nDestructured Weapons:");
# console.log("Main Weapon:", mainWeapon);
# console.log("Secondary Weapon:", secondaryWeapon);
# console.log("Special Weapon:", specialWeapon);
#
# // Spread operator with arrays
# let baseInventory = ["potion", "key"];
# let bonusItems = ["scythe", "shield"];
# let fullInventory = [...baseInventory, ...bonusItems];
# console.log("\nSpread Operator:");
# console.log("Base Inventory:", baseInventory);
# console.log("Bonus Items:", bonusItems);
# console.log("Full Inventory:", fullInventory);
#
# // Array of objects for complex game data
# let gameObjects = [
#     { id: 1, type: "player", x: 100, y: 100, health: 100 },
#     { id: 2, type: "boss", x: 300, y: 200, health: 150 },
#     { id: 3, type: "projectile", x: 150, y: 120, damage: 10 },
#     { id: 4, type: "item", x: 200, y: 150, itemType: "key" }
# ];
#
# console.log("\nArray of Objects:");
# console.log("All Objects:", gameObjects);
# console.log("Player Object:", gameObjects.find(obj => obj.type === "player"));
# console.log("Boss Object:", gameObjects.find(obj => obj.type === "boss"));
# console.log("All Projectiles:", gameObjects.filter(obj => obj.type === "projectile"));
# {% endcapture %}
#
# {% include code-runner.html
#    runner_id="arrays_exercise"
#    language="javascript"
#    code=code_arrays
# %}

# %% [markdown]
# ### Objects (JSON)
#
# {% capture code_objects %}
# // Fortress Level 6 - Game objects and JSON
# let player = {
#     name: "Hero",
#     health: 85,
#     maxHealth: 100,
#     level: 6,
#     position: { x: 250, y: 180 },
#     weapons: ["sword", "bow", "scythe"],
#     hasKey: false,
#     isAlive: true
# };
#
# console.log("Player Object:", player);
#
# // Accessing object properties
# console.log("Player Name:", player.name);
# console.log("Player Position X:", player.position.x);
# console.log("Player Weapons:", player.weapons);
#
# // Adding and modifying properties
# player.score = 15000;
# player.health = 90;
# player.currentRoom = "bossBattleRoom";
# console.log("Updated Player:", player);
#
# // Deleting properties
# delete player.isAlive;
# console.log("After deleting isAlive:", player);
#
# // Object methods
# console.log("Object Keys:", Object.keys(player));
# console.log("Object Values:", Object.values(player));
# console.log("Object Entries:", Object.entries(player));
#
# // Checking if property exists
# console.log("Has 'weapons':", player.hasOwnProperty('weapons'));
# console.log("Has 'isAlive':", player.hasOwnProperty('isAlive'));
# console.log("'score' in player:", 'score' in player);
#
# // Nested objects for game state
# let gameState = {
#     level: {
#         name: "mansionLevel6",
#         currentRoom: "bossBattleRoom",
#         difficulty: "hard"
#     },
#     player: {
#         stats: {
#             health: 85,
#             maxHealth: 100,
#             attack: 15,
#             defense: 10
#         },
#         inventory: {
#             weapons: ["sword", "bow", "scythe"],
#             items: ["health_potion", "key"],
#             quantity: {
#                 "health_potion": 3,
#                 "key": 1
#             }
#         },
#         position: { x: 250, y: 180 }
#     },
#     boss: {
#         name: "The Reaper",
#         health: 100,
#         maxHealth: 150,
#         stage: 2,
#         attacks: ["melee", "arrow", "fireball", "scythe"],
#         position: { x: 400, y: 300 }
#     }
# };
#
# console.log("Nested Game State:", gameState);
# console.log("Player Attack:", gameState.player.stats.attack);
# console.log("Boss Stage:", gameState.boss.stage);
# console.log("Scythe in Inventory:", gameState.player.inventory.weapons.includes('scythe'));
#
# // Object methods for game mechanics
# let gameMethods = {
#     calculateDamage: function(baseDamage, weaponMultiplier, criticalHit = false) {
#         let damage = baseDamage * weaponMultiplier;
#         if (criticalHit) damage *= 2;
#         return Math.round(damage);
#     },
#
#     getDistance: function(obj1, obj2) {
#         let dx = obj1.position.x - obj2.position.x;
#         let dy = obj1.position.y - obj2.position.y;
#         return Math.sqrt(dx * dx + dy * dy);
#     },
#
#     isInAttackRange: function(attacker, defender, range) {
#         return this.getDistance(attacker, defender) <= range;
#     }
# };
#
# console.log("Game Methods:");
# console.log("Scythe Damage:", gameMethods.calculateDamage(20, 1.5, true));
# console.log("Distance to Boss:", gameMethods.getDistance(player, gameState.boss));
# console.log("In Attack Range:", gameMethods.isInAttackRange(player, gameState.boss, 200));
#
# // Object destructuring
# let { name, health, weapons } = player;
# console.log("Destructured Player:", name, health, weapons);
#
# let { position: { x, y } } = player;
# console.log("Destructured Position:", x, y);
#
# // Spread operator with objects
# let playerCopy = { ...player, status: "fighting" };
# console.log("Copied and Extended:", playerCopy);
#
# // JSON operations for game save/load
# let gameStateJSON = JSON.stringify(gameState);
# console.log("Game State as JSON:", gameStateJSON);
#
# let parsedGameState = JSON.parse(gameStateJSON);
# console.log("Parsed Game State:", parsedGameState);
#
# // Object.assign for merging game configurations
# let defaultConfig = {
#     volume: 0.8,
#     difficulty: "normal",
#     graphics: "high",
#     controls: "keyboard"
# };
#
# let userConfig = {
#     volume: 0.6,
#     difficulty: "hard"
# };
#
# let finalConfig = Object.assign({}, defaultConfig, userConfig);
# console.log("Merged Configuration:", finalConfig);
#
# // Dynamic property names for game data
# let weaponStats = "scythe";
# let weaponData = {
#     [weaponStats]: {
#         damage: 20,
#         range: 150,
#         speed: 1.2,
#         special: "elliptical"
#     },
#     ["bow"]: {
#         damage: 10,
#         range: 300,
#         speed: 2.0,
#         special: "straight"
#     }
# };
#
# console.log("Dynamic Weapon Data:", weaponData);
# console.log("Scythe Stats:", weaponData.scythe);
#
# // Object methods for game validation
# function validatePlayer(playerData) {
#     return playerData &&
#            typeof playerData.name === 'string' &&
#            typeof playerData.health === 'number' &&
#            playerData.health >= 0 &&
#            playerData.health <= playerData.maxHealth &&
#            Array.isArray(playerData.weapons);
# }
#
# function validateBoss(bossData) {
#     return bossData &&
#            typeof bossData.name === 'string' &&
#            typeof bossData.health === 'number' &&
#            bossData.health >= 0 &&
#            Array.isArray(bossData.attacks);
# }
#
# console.log("\nValidation:");
# console.log("Player is valid:", validatePlayer(player));
# console.log("Boss is valid:", validateBoss(gameState.boss));
#
# // Object iteration for game debugging
# console.log("\nPlayer Properties:");
# for (let key in player) {
#     if (player.hasOwnProperty(key)) {
#         console.log(`${key}: ${player[key]}`);
#     }
# }
#
# // Object.entries for game data processing
# console.log("\nPlayer Data Entries:");
# Object.entries(player).forEach(([key, value]) => {
#     console.log(`${key}: ${typeof value} = ${value}`);
# });
#
# // Practical game object creation
# function createProjectile(type, sourceX, sourceY, targetX, targetY) {
#     return {
#         type: type,
#         position: { x: sourceX, y: sourceY },
#         target: { x: targetX, y: targetY },
#         damage: type === 'scythe' ? 20 : type === 'fireball' ? 15 : 10,
#         speed: type === 'scythe' ? 1.2 : 2.0,
#         active: true,
#         createdAt: Date.now()
#     };
# }
#
# let scytheProjectile = createProjectile('scythe', 250, 180, 400, 300);
# console.log("\nCreated Projectile:", scytheProjectile);
# {% endcapture %}
#
# {% include code-runner.html
#    runner_id="objects_exercise"
#    language="javascript"
#    code=code_objects
# %}

# %% [markdown]
# ### Operators
#
# {% capture code_operators %}
# // Fortress Level 6 - Game operators
# // Arithmetic operators for game calculations
# let playerHealth = 85;
# let bossHealth = 100;
# let scytheDamage = 20;
# let fireballDamage = 15;
#
# console.log("Game Arithmetic:");
# console.log("Player Health + Healing Potion:", playerHealth + 25);
# console.log("Boss Health - Scythe Damage:", bossHealth - scytheDamage);
# console.log("Damage Multiplier * Base Damage:", 1.5 * scytheDamage);
# console.log("Total Damage / Number of Hits:", (scytheDamage + fireballDamage) / 2);
# console.log("Experience Points % Level Bonus:", 1500 % 100);
# console.log("Critical Hit Multiplier ** 2:", 2 ** 2);
#
# // Assignment operators for game state updates
# let playerScore = 1000;
# console.log("\nGame Assignment:");
# console.log("Initial Score:", playerScore);
# playerScore += 500;  // Boss defeated bonus
# console.log("After Boss Bonus:", playerScore);
# playerScore -= 100;  // Damage taken penalty
# console.log("After Damage Penalty:", playerScore);
# playerScore *= 2;   // Double score event
# console.log("After Double Score:", playerScore);
# playerScore /= 4;   // Score reduction
# console.log("After Division:", playerScore);
#
# // Comparison operators for game conditions
# let playerLevel = 6;
# let requiredLevel = 5;
# let bossStage = 2;
# let playerHasKey = true;
#
# console.log("\nGame Comparisons:");
# console.log("Player Level >= Required:", playerLevel >= requiredLevel);
# console.log("Boss Stage == 2 (loose):", bossStage == "2");
# console.log("Boss Stage === 2 (strict):", bossStage === 2);
# console.log("Player Level != Required:", playerLevel != requiredLevel);
# console.log("Player Level !== '6':", playerLevel !== "6");
# console.log("Boss Health > 50:", bossHealth > 50);
# console.log("Player Health <= 100:", playerHealth <= 100);
#
# // Logical operators for game logic
# let canEnterBossRoom = playerHasKey && playerLevel >= requiredLevel;
# let isGameOver = playerHealth <= 0 || bossHealth <= 0;
# let shouldHeal = playerHealth < 50 && !isGameOver;
#
# console.log("\nGame Logic:");
# console.log("Can Enter Boss Room:", canEnterBossRoom);
# console.log("Is Game Over:", isGameOver);
# console.log("Should Heal:", shouldHeal);
# console.log("NOT Game Over:", !isGameOver);
#
# // Unary operators for game counters
# let comboCount = 0;
# console.log("\nGame Counters:");
# console.log("Initial Combo:", comboCount);
# console.log("++Combo (pre):", ++comboCount);
# console.log("Combo++ (post):", comboCount++);
# console.log("Current Combo:", comboCount);
# console.log("--Combo (pre):", --comboCount);
# console.log("Combo-- (post):", comboCount--);
# console.log("Final Combo:", comboCount);
#
# // Ternary operator for game decisions
# let playerPosition = { x: 250, y: 180 };
# let bossPosition = { x: 400, y: 300 };
# let distance = Math.sqrt(Math.pow(bossPosition.x - playerPosition.x, 2) +
#                         Math.pow(bossPosition.y - playerPosition.y, 2));
#
# let attackType = distance < 200 ? "melee" : "ranged";
# let dangerLevel = playerHealth > 70 ? "safe" : playerHealth > 40 ? "moderate" : "critical";
#
# console.log("\nGame Decisions:");
# console.log("Attack Type:", attackType);
# console.log("Danger Level:", dangerLevel);
#
# // typeof operator for game type checking
# let gameState = {
#     player: "Hero",
#     bossHealth: 100,
#     hasScythe: true,
#     weapons: ["sword", "bow", "scythe"],
#     position: { x: 250, y: 180 }
# };
#
# console.log("\nGame Type Checking:");
# console.log("typeof gameState.player:", typeof gameState.player);
# console.log("typeof gameState.bossHealth:", typeof gameState.bossHealth);
# console.log("typeof gameState.hasScythe:", typeof gameState.hasScythe);
# console.log("typeof gameState.weapons:", typeof gameState.weapons);
# console.log("typeof gameState.position:", typeof gameState.position);
#
# // instanceof operator for game objects
# let gameSprite = new Image();
# let currentDate = new Date();
#
# console.log("\nGame Instance Checking:");
# console.log("gameSprite instanceof Image:", gameSprite instanceof Image);
# console.log("currentDate instanceof Date:", currentDate instanceof Date);
# console.log("gameState.weapons instanceof Array:", gameState.weapons instanceof Array);
#
# // in operator for game property checking
# console.log("\nGame Property Checking:");
# console.log("'player' in gameState:", 'player' in gameState);
# console.log("'scythe' in gameState.weapons:", 'scythe' in gameState.weapons);
# console.log("'length' in gameState.weapons:", 'length' in gameState.weapons);
#
# // Nullish coalescing operator for game defaults
# let playerInventory = null;
# let defaultInventory = ["sword", "potion"];
# let playerScore2 = 0;
# let defaultScore = 100;
#
# console.log("\nGame Default Values:");
# console.log("Player Inventory ?? Default:", playerInventory ?? defaultInventory);
# console.log("Player Score ?? Default:", playerScore2 ?? defaultScore);
# console.log("Player Health ?? Default:", playerHealth ?? 50);
#
# // Optional chaining operator for nested game data
# let gameData = {
#     player: {
#         stats: {
#             health: 85,
#             attack: 15
#         }
#     }
# };
#
# console.log("\nGame Optional Chaining:");
# console.log("Player Health:", gameData?.player?.stats?.health);
# console.log("Player Mana:", gameData?.player?.stats?.mana ?? "Not available");
# console.log("Boss Data:", gameData?.boss?.stats?.health ?? "No boss data");
#
# // Game-specific operator combinations
# function evaluateCombatSituation(player, boss) {
#     let playerAdvantage = player.health > 50 && player.hasScythe;
#     let bossAdvantage = boss.health > 70 && boss.stage >= 2;
#     let canWin = playerAdvantage && !bossAdvantage;
#     let shouldRetreat = !playerAdvantage && bossAdvantage;
#
#     return {
#         playerAdvantage,
#         bossAdvantage,
#         canWin,
#         shouldRetreat,
#         recommendation: canWin ? "Attack!" : shouldRetreat ? "Retreat!" : "Caution!"
#     };
# }
#
# let player = { health: 85, hasScythe: true };
# let boss = { health: 100, stage: 2 };
#
# let combatEval = evaluateCombatSituation(player, boss);
# console.log("\nCombat Evaluation:");
# console.log("Player Advantage:", combatEval.playerAdvantage);
# console.log("Boss Advantage:", combatEval.bossAdvantage);
# console.log("Can Win:", combatEval.canWin);
# console.log("Recommendation:", combatEval.recommendation);
# {% endcapture %}
#
# {% include code-runner.html
#    runner_id="operators_exercise"
#    language="javascript"
#    code=code_operators
# %}

# %% [markdown]
# ### Mathematical
#
# {% capture code_mathematical %}
# // Fortress Level 6 - Game mathematics and physics
# // Basic Math constants for game calculations
# console.log("Game Math Constants:");
# console.log("PI (for circular attacks):", Math.PI);
# console.log("E (for exponential growth):", Math.E);
# console.log("LN2 (for logarithmic scaling):", Math.LN2);
# console.log("SQRT2 (for diagonal movement):", Math.SQRT2);
#
# // Player and boss positions
# let playerPos = { x: 250, y: 180 };
# let bossPos = { x: 400, y: 300 };
#
# // Distance calculation using Pythagorean theorem
# let distance = Math.sqrt(Math.pow(bossPos.x - playerPos.x, 2) +
#                        Math.pow(bossPos.y - playerPos.y, 2));
# console.log("\nDistance Calculations:");
# console.log("Distance to Boss:", distance.toFixed(2));
#
# // Basic mathematical operations for combat
# let baseDamage = 15;
# let weaponMultiplier = 1.5;
# let criticalHit = true;
# let totalDamage = baseDamage * weaponMultiplier * (criticalHit ? 2 : 1);
#
# console.log("\nCombat Math:");
# console.log("Base Damage:", baseDamage);
# console.log("Weapon Multiplier:", weaponMultiplier);
# console.log("Total Damage:", totalDamage);
#
# // Rounding functions for game stats
# let experience = 1234.567;
# let healthPercentage = 87.3;
#
# console.log("\nRounding Functions:");
# console.log("Experience rounded:", Math.round(experience));
# console.log("Experience floored:", Math.floor(experience));
# console.log("Experience ceiling:", Math.ceil(experience));
# console.log("Health truncated:", Math.trunc(healthPercentage));
#
# // Trigonometry for scythe elliptical trajectory
# let scytheProgress = 0.785; // radians (45 degrees)
# let ellipseWidth = 150;
# let ellipseHeight = 60;
#
# let scytheX = ellipseWidth * Math.cos(scytheProgress);
# let scytheY = ellipseHeight * Math.sin(scytheProgress);
#
# console.log("\nScythe Trajectory Math:");
# console.log("Progress (radians):", scytheProgress);
# console.log("Cosine:", Math.cos(scytheProgress).toFixed(3));
# console.log("Sine:", Math.sin(scytheProgress).toFixed(3));
# console.log("Scythe X Position:", scytheX.toFixed(2));
# console.log("Scythe Y Position:", scytheY.toFixed(2));
#
# // Boss attack angles
# let bossAttackAngle = Math.atan2(playerPos.y - bossPos.y, playerPos.x - bossPos.x);
# console.log("\nBoss Attack Math:");
# console.log("Attack Angle (radians):", bossAttackAngle.toFixed(3));
# console.log("Attack Angle (degrees):", (bossAttackAngle * 180 / Math.PI).toFixed(1));
#
# // Random number generation for game events
# console.log("\nRandom Game Events:");
# console.log("Random Boss Damage:", Math.floor(Math.random() * 20) + 5); // 5-25 damage
# console.log("Critical Hit Chance:", Math.random() < 0.2 ? "CRITICAL!" : "Normal hit");
# console.log("Random Item Drop:", Math.random() < 0.3 ? "Item Dropped!" : "No drop");
#
# // Min/Max for game boundaries
# let gameWorld = {
#     minX: 0, maxX: 800,
#     minY: 0, maxY: 600
# };
#
# let playerX = Math.max(gameWorld.minX, Math.min(gameWorld.maxX, playerPos.x));
# let playerY = Math.max(gameWorld.minY, Math.min(gameWorld.maxY, playerPos.y));
#
# console.log("\nBoundary Math:");
# console.log("Clamped Player X:", playerX);
# console.log("Clamped Player Y:", playerY);
#
# // Exponential and logarithmic functions for game progression
# let playerLevel = 6;
# let experienceNeeded = Math.pow(2, playerLevel) * 100;
# let currentExp = 850;
#
# console.log("\nProgression Math:");
# console.log("Experience Needed for Level 6:", experienceNeeded);
# console.log("Current Experience:", currentExp);
# console.log("Experience Progress:", (currentExp / experienceNeeded * 100).toFixed(1) + "%");
#
# // Health regeneration using exponential decay
# let maxHealth = 100;
# let currentHealth = 45;
# let regenerationRate = 0.05;
# let timePassed = 10; // seconds
#
# let regeneratedHealth = currentHealth + (maxHealth - currentHealth) * (1 - Math.exp(-regenerationRate * timePassed));
# console.log("Health after regeneration:", Math.min(maxHealth, regeneratedHealth).toFixed(1));
#
# // Scythe elliptical orbit calculations
# function calculateScythePosition(progress, sourceX, sourceY, targetX, targetY) {
#     let centerX = (sourceX + targetX) / 2;
#     let centerY = (sourceY + targetY) / 2;
#     let width = Math.sqrt(Math.pow(targetX - sourceX, 2) + Math.pow(targetY - sourceY, 2));
#     let height = width / 4;
#     let angle = Math.atan2(targetY - sourceY, targetX - sourceX);
#
#     let x = centerX + (width / 2) * Math.cos(progress) * Math.cos(angle) -
#                 height * Math.sin(progress) * Math.sin(angle);
#     let y = centerY + (width / 2) * Math.cos(progress) * Math.sin(angle) +
#                 height * Math.sin(progress) * Math.cos(angle);
#
#     return { x, y };
# }
#
# console.log("\nAdvanced Scythe Math:");
# let scythePositions = [];
# for (let i = 0; i <= 8; i++) {
#     let progress = (i / 8) * 2 * Math.PI;
#     let pos = calculateScythePosition(progress, 250, 180, 400, 300);
#     scythePositions.push(`Step ${i}: (${pos.x.toFixed(1)}, ${pos.y.toFixed(1)})`);
# }
# console.log("Scythe Trajectory Points:");
# scythePositions.forEach(point => console.log(point));
#
# // Game physics calculations
# function calculateProjectileVelocity(sourceX, sourceY, targetX, targetY, speed) {
#     let dx = targetX - sourceX;
#     let dy = targetY - sourceY;
#     let distance = Math.sqrt(dx * dx + dy * dy);
#     let time = distance / speed;
#
#     return {
#         vx: dx / time,
#         vy: dy / time,
#         time: time
#     };
# }
#
# let projectile = calculateProjectileVelocity(250, 180, 400, 300, 200);
# console.log("\nProjectile Physics:");
# console.log("Velocity X:", projectile.vx.toFixed(2));
# console.log("Velocity Y:", projectile.vy.toFixed(2));
# console.log("Time to Target:", projectile.time.toFixed(2) + " seconds");
#
# // Damage calculation with armor reduction
# function calculateDamage(baseDamage, armor, criticalMultiplier = 1) {
#     let damage = baseDamage * criticalMultiplier;
#     let reduction = damage * (armor / (armor + 100));
#     return Math.max(1, damage - reduction);
# }
#
# let bossArmor = 25;
# let playerDamage = calculateDamage(20, bossArmor, 2); // Critical hit
# console.log("\nArmor Math:");
# console.log("Base Damage: 20");
# console.log("Boss Armor:", bossArmor);
# console.log("Critical Damage after armor:", playerDamage.toFixed(1));
#
# // Area of effect calculations
# function calculateAreaOfEffect(centerX, centerY, radius) {
#     return Math.PI * Math.pow(radius, 2);
# }
#
# let explosionRadius = 50;
# let aoeArea = calculateAreaOfEffect(400, 300, explosionRadius);
# console.log("\nArea of Effect Math:");
# console.log("Explosion Radius:", explosionRadius);
# console.log("Area of Effect:", aoeArea.toFixed(1) + " square units");
#
# // Number validation for game inputs
# function validateGameInput(value, min, max, type = "number") {
#     if (type === "number") {
#         let num = Number(value);
#         return !isNaN(num) && num >= min && num <= max;
#     }
#     return false;
# }
#
# console.log("\nInput Validation:");
# console.log("Valid health (85):", validateGameInput(85, 0, 100));
# console.log("Invalid health (-5):", validateGameInput(-5, 0, 100));
# console.log("Invalid health (150):", validateGameInput(150, 0, 100));
# console.log("Invalid health ('abc'):", validateGameInput("abc", 0, 100));
# {% endcapture %}
#
# {% include code-runner.html
#    runner_id="mathematical_exercise"
#    language="javascript"
#    code=code_mathematical
# %}

# %% [markdown]
# ### String Operations
#
# {% capture code_string_operations %}
# // Fortress Level 6 - Game string operations
# // String concatenation for game messages
# let playerName = "Hero";
# let weaponName = "Scythe";
# let bossName = "The Reaper";
# let damageAmount = "20";
#
# let combatMessage = playerName + " attacks " + bossName + " with " + weaponName + " for " + damageAmount + " damage!";
# let templateMessage = `${playerName} attacks ${bossName} with ${weaponName} for ${damageAmount} damage!`;
#
# console.log("Combat Messages:");
# console.log("Concatenated:", combatMessage);
# console.log("Template literal:", templateMessage);
#
# // String properties for game data
# let gameTitle = "Fortress of the Reaper";
# let playerStatus = "Health: 85/100 | Room: bossBattleRoom";
#
# console.log("\nString Properties:");
# console.log("Game Title:", gameTitle);
# console.log("Title Length:", gameTitle.length);
# console.log("First Character:", gameTitle[0]);
# console.log("Last Character:", gameTitle[gameTitle.length - 1]);
#
# // Case conversion for game text
# let dialogue = "THE REAPER: YOUR JOURNEY ENDS HERE!";
# let whisper = "the reaper whispers: you cannot escape...";
#
# console.log("\nCase Conversion:");
# console.log("Original Dialogue:", dialogue);
# console.log("Lowercase:", dialogue.toLowerCase());
# console.log("Uppercase Whisper:", whisper.toUpperCase());
#
# // Searching within game strings
# let gameLog = "Player entered bossBattleRoom, found scythe, attacked The Reaper for 20 damage";
# console.log("\nString Searching:");
# console.log("Game Log:", gameLog);
# console.log("Contains 'scythe':", gameLog.includes('scythe'));
# console.log("Position of 'Reaper':", gameLog.indexOf('Reaper'));
# console.log("Starts with 'Player':", gameLog.startsWith('Player'));
# console.log("Ends with 'damage':", gameLog.endsWith('damage'));
#
# // Extracting substrings for game data
# let fullStatus = "Health: 85/100 | Mana: 30/50 | Room: bossBattleRoom";
# console.log("\nString Extraction:");
# console.log("Full Status:", fullStatus);
# console.log("Health Part:", fullStatus.slice(0, 14));
# console.log("Room Part:", fullStatus.slice(fullStatus.indexOf('Room:') + 6));
# console.log("Mana Part:", fullStatus.substring(16, 26));
#
# // Splitting strings for game inventory
# let inventoryString = "sword,shield,health_potion,scythe,key";
# let questItems = "find_key|defeat_reaper|escape_fortress";
#
# console.log("\nString Splitting:");
# console.log("Inventory String:", inventoryString);
# console.log("Inventory Array:", inventoryString.split(','));
# console.log("Quest Items:", questItems.split('|'));
#
# // Replacing content in game updates
# let oldStatus = "Player is exploring the fortress";
# let newStatus = oldStatus.replace("exploring", "fighting");
# let multipleReplace = "Player health: 80, Player mana: 40".replace(/Player/g, "Hero");
#
# console.log("\nString Replacement:");
# console.log("Old Status:", oldStatus);
# console.log("New Status:", newStatus);
# console.log("Multiple Replace:", multipleReplace);
#
# // Trimming whitespace for user input
# let userInput = "   scythe   ";
# let chatInput = "   The Reaper awaits...   ";
#
# console.log("\nString Trimming:");
# console.log("Weapon Input:", "'" + userInput + "' -> '" + userInput.trim() + "'");
# console.log("Chat Input:", "'" + chatInput + "' -> '" + chatInput.trim() + "'");
# console.log("Trim Start:", "'" + chatInput + "' -> '" + chatInput.trimStart() + "'");
# console.log("Trim End:", "'" + chatInput + "' -> '" + chatInput.trimEnd() + "'");
#
# // Padding strings for UI display
# let levelNumber = "6";
# let score = "1500";
#
# console.log("\nString Padding:");
# console.log("Level:", levelNumber.padStart(3, '0'));
# console.log("Score:", score.padEnd(8, '0'));
#
# // Repeating strings for effects
# let criticalText = "CRITICAL! ";
# let damageText = "DAMAGE: ";
#
# console.log("\nString Repetition:");
# console.log("Critical Hit:", criticalText.repeat(3));
# console.log("Damage Display:", damageText.repeat(2) + "20");
#
# // Character codes for game symbols
# console.log("\nCharacter Codes:");
# console.log("Heart Symbol:", String.fromCharCode(9829)); // ♥
# console.log("Skull Symbol:", String.fromCharCode(9760)); // ☠
# console.log("Sword Symbol:", String.fromCharCode(9876)); // ⚔
# console.log("'A' char code:", "A".charCodeAt(0));
#
# // String comparison for game logic
# let weapon1 = "Scythe of Shadows";
# let weapon2 = "scythe of shadows";
# let room1 = "bossBattleRoom";
# let room2 = "BossBattleRoom";
#
# console.log("\nString Comparison:");
# console.log("Exact Match:", weapon1 === weapon2);
# console.log("Case Insensitive:", weapon1.toLowerCase() === weapon2.toLowerCase());
# console.log("Room Comparison:", room1 === room2);
# console.log("Locale Compare:", weapon1.localeCompare(weapon2));
#
# // Practical game string functions
# function formatHealthBar(health, maxHealth) {
#     let percentage = Math.floor((health / maxHealth) * 100);
#     let bar = "█".repeat(Math.floor(percentage / 10)) + "░".repeat(10 - Math.floor(percentage / 10));
#     return `${health}/${maxHealth} [${bar}] ${percentage}%`;
# }
#
# function getBossTaunt(bossStage) {
#     const taunts = [
#         "You stand no chance!",
#         "The fortress will be your tomb!",
#         "My scythe is hungry!",
#         "Your journey ends now!",
#         "Flee while you can!"
#     ];
#     return taunts[Math.floor(Math.random() * taunts.length)];
# }
#
# function parseGameCommand(command) {
#     let parts = command.trim().toLowerCase().split(' ');
#     let action = parts[0];
#     let target = parts.slice(1).join(' ');
#     return { action, target };
# }
#
# console.log("\nGame String Functions:");
# console.log("Health Bar:", formatHealthBar(75, 100));
# console.log("Boss Taunt:", getBossTaunt(2));
# console.log("Parsed Command:", parseGameCommand("attack reaper with scythe"));
#
# // String to number conversion for game stats
# function convertGameStats(str) {
#     let numbers = str.match(/\d+/g);
#     return numbers ? numbers.map(Number) : [];
# }
#
# let statString = "Player: Level 6, Health 85, Attack 20, Defense 15";
# let extractedStats = convertGameStats(statString);
#
# console.log("\nString to Number Conversion:");
# console.log("Stat String:", statString);
# console.log("Extracted Numbers:", extractedStats);
#
# // Advanced string processing for game dialogue
# function processDialogue(dialogue, playerName) {
#     return dialogue
#         .replace(/\[PLAYER\]/g, playerName)
#         .replace(/\[HEALTH\]/g, "85")
#         .replace(/\[WEAPON\]/g, "Scythe")
#         .replace(/\[BOSS\]/g, "The Reaper");
# }
#
# let templateDialogue = "[PLAYER]: I will defeat [BOSS] with my [WEAPON]! My [HEALTH] is still high!";
# let processedDialogue = processDialogue(templateDialogue, "Hero");
#
# console.log("\nDialogue Processing:");
# console.log("Template:", templateDialogue);
# console.log("Processed:", processedDialogue);
#
# // String validation for game input
# function validatePlayerName(name) {
#     return /^[a-zA-Z0-9_]{3,20}$/.test(name);
# }
#
# function validateRoomCode(code) {
#     return /^[A-Z]{3}-\d{4}$/.test(code);
# }
#
# console.log("\nString Validation:");
# console.log("Valid Name 'Hero123':", validatePlayerName("Hero123"));
# console.log("Invalid Name 'H!':", validatePlayerName("H!"));
# console.log("Valid Room Code 'ABC-1234':", validateRoomCode("ABC-1234"));
# console.log("Invalid Room Code 'abc-123':", validateRoomCode("abc-123"));
#
# // String formatting for game display
# function formatGameTime(seconds) {
#     let hours = Math.floor(seconds / 3600);
#     let minutes = Math.floor((seconds % 3600) / 60);
#     let secs = seconds % 60;
#     return `${hours.toString().padStart(2, '0')}:${minutes.toString().padStart(2, '0')}:${secs.toString().padStart(2, '0')}`;
# }
#
# console.log("\nTime Formatting:");
# console.log("3661 seconds:", formatGameTime(3661));
# console.log("125 seconds:", formatGameTime(125));
# console.log("5 seconds:", formatGameTime(5));
# {% endcapture %}
#
# {% include code-runner.html
#    runner_id="string_operations_exercise"
#    language="javascript"
#    code=code_string_operations
# %}

# %% [markdown]
# ### Boolean Expressions
#
# {% capture code_boolean_expressions %}
# // Fortress Level 6 - Game boolean expressions
# // Basic comparison expressions
# let playerHealth = 85;
# let bossHealth = 100;
# let playerLevel = 6;
# let requiredLevel = 5;
# let hasScythe = true;
# let hasKey = false;
#
# console.log("Basic Comparisons:");
# console.log("Player Health >= 50:", playerHealth >= 50);
# console.log("Boss Health < 100:", bossHealth < 100);
# console.log("Player Level == Required:", playerLevel == requiredLevel);
# console.log("Player Level === 6:", playerLevel === 6);
# console.log("Has Scythe !== Has Key:", hasScythe !== hasKey);
#
# // Logical expressions for game conditions
# let canEnterBossRoom = hasKey && playerLevel >= requiredLevel;
# let isGameOver = playerHealth <= 0 || bossHealth <= 0;
# let shouldHeal = playerHealth < 50 && !isGameOver;
# let canUseSpecialAttack = hasScythe && playerHealth > 30;
#
# console.log("\nGame Logic Expressions:");
# console.log("Can Enter Boss Room:", canEnterBossRoom);
# console.log("Is Game Over:", isGameOver);
# console.log("Should Heal:", shouldHeal);
# console.log("Can Use Special Attack:", canUseSpecialAttack);
#
# // Complex boolean expressions with functions
# function isPlayerInDanger(health, bossHealth, bossStage) {
#     return health < 30 || (health < 50 && bossHealth > 70 && bossStage >= 2);
# }
#
# function shouldUseScythe(distance, bossStage, playerMana) {
#     return distance < 200 && bossStage >= 2 && playerMana >= 30;
# }
#
# function canWinBattle(playerHealth, hasScythe, bossStage, playerLevel) {
#     return playerHealth > 40 && hasScythe && bossStage < 3 && playerLevel >= 5;
# }
#
# console.log("\nComplex Game Conditions:");
# console.log("Player in Danger:", isPlayerInDanger(25, 80, 2));
# console.log("Should Use Scythe:", shouldUseScythe(150, 2, 40));
# console.log("Can Win Battle:", canWinBattle(75, true, 2, 6));
#
# // Short-circuit evaluation in game context
# function processGameEvent(event, playerData) {
#     // Only process if player is alive
#     if (playerData.isAlive && event.type === "combat") {
#         console.log("Processing combat event...");
#         return true;
#     }
#
#     // Default to false for dead players or non-combat events
#     console.log("Cannot process event");
#     return false;
# }
#
# let alivePlayer = { isAlive: true, health: 85 };
# let deadPlayer = { isAlive: false, health: 0 };
#
# console.log("\nShort-circuit Evaluation:");
# console.log("Alive Player Combat:", processGameEvent({type: "combat"}, alivePlayer));
# console.log("Dead Player Combat:", processGameEvent({type: "combat"}, deadPlayer));
#
# // Truthy and falsy values in game scenarios
# console.log("\nTruthy/Falsy Game Values:");
# console.log("Empty Inventory (falsy):", Boolean([]));
# console.log("No Weapons (falsy):", Boolean(""));
# console.log("Zero Health (falsy):", Boolean(0));
# console.log("No Position (falsy):", Boolean(null));
# console.log("Undefined Item (falsy):", Boolean(undefined));
# console.log("Valid Health (truthy):", Boolean(85));
# console.log("Weapon Array (truthy):", Boolean(["sword", "scythe"]));
#
# // Boolean expressions with arrays
# let playerInventory = ["sword", "potion", "scythe"];
# let bossAttacks = ["melee", "arrow", "fireball", "scythe"];
#
# function hasWeapon(inventory, weapon) {
#     return inventory.includes(weapon);
# }
#
# function canCounterAttack(bossAttacks, playerWeapons) {
#     return bossAttacks.some(attack =>
#         playerWeapons.some(weapon =>
#             weapon === attack || (weapon === "shield" && attack === "melee")
#         )
#     );
# }
#
# console.log("\nArray Boolean Expressions:");
# console.log("Has Scythe:", hasWeapon(playerInventory, "scythe"));
# console.log("Has Magic:", hasWeapon(playerInventory, "magic"));
# console.log("Can Counter Attack:", canCounterAttack(bossAttacks, playerInventory));
#
# // Boolean expressions with objects
# let gameState = {
#     player: {
#         health: 85,
#         weapons: ["sword", "scythe"],
#         position: { x: 250, y: 180 },
#         isAlive: true
#     },
#     boss: {
#         health: 100,
#         stage: 2,
#         attacks: ["melee", "arrow", "fireball"]
#     },
#     level: {
#         currentRoom: "bossBattleRoom",
#         difficulty: "hard"
#     }
# };
#
# function isPlayerReady(player) {
#     return player.health > 50 &&
#            player.weapons.length > 0 &&
#            player.isAlive &&
#            player.position.x !== undefined;
# }
#
# function isBossThreat(boss) {
#     return boss.health > 0 &&
#            boss.attacks.length > 0 &&
#            boss.stage >= 1;
# }
#
# console.log("\nObject Boolean Expressions:");
# console.log("Player Ready:", isPlayerReady(gameState.player));
# console.log("Boss Threat:", isBossThreat(gameState.boss));
#
# // Complex validation with boolean expressions
# function validateGameState(state) {
#     return state &&
#            state.player && state.boss && state.level &&
#            typeof state.player.health === 'number' &&
#            state.player.health >= 0 && state.player.health <= 100 &&
#            Array.isArray(state.player.weapons) &&
#            state.player.weapons.length > 0 &&
#            typeof state.boss.health === 'number' &&
#            state.boss.health >= 0 &&
#            typeof state.level.currentRoom === 'string';
# }
#
# console.log("\nGame State Validation:");
# console.log("Game State Valid:", validateGameState(gameState));
#
# // Boolean expressions for game physics
# function isInAttackRange(attacker, defender, range) {
#     let distance = Math.sqrt(
#         Math.pow(attacker.x - defender.x, 2) +
#         Math.pow(attacker.y - defender.y, 2)
#     );
#     return distance <= range;
# }
#
# function canDodge(projectile, player) {
#     return projectile.speed < 5 &&
#            player.health > 30 &&
#            Math.abs(projectile.x - player.x) > 50;
# }
#
# let player = { x: 250, y: 180, health: 85 };
# let boss = { x: 400, y: 300 };
# let projectile = { x: 300, y: 200, speed: 3 };
#
# console.log("\nPhysics Boolean Expressions:");
# console.log("In Attack Range:", isInAttackRange(player, boss, 200));
# console.log("Can Dodge:", canDodge(projectile, player));
#
# // Boolean expressions for game progression
# function checkLevelCompletion(player, boss, hasKey) {
#     let bossDefeated = boss.health <= 0;
#     let playerAlive = player.health > 0;
#     let hasRequiredItem = hasKey;
#
#     return bossDefeated && playerAlive && hasRequiredItem;
# }
#
# function shouldTriggerCutscene(playerHealth, bossHealth, currentStage) {
#     return (playerHealth < 20 && bossHealth > 80) ||
#            (bossHealth < 30 && currentStage === "final") ||
#            (playerHealth > 90 && bossHealth < 10);
# }
#
# console.log("\nProgression Boolean Expressions:");
# console.log("Level Complete:", checkLevelCompletion({health: 75}, {health: 0}, true));
# console.log("Trigger Cutscene:", shouldTriggerCutscene(15, 85, "battle"));
#
# // De Morgan's laws in game logic
# function demonstrateDeMorgan() {
#     let hasWeapon = true;
#     let hasMana = false;
#     let isAlive = true;
#
#     // Original: !(hasWeapon && hasMana)
#     let notBoth = !(hasWeapon && hasMana);
#
#     // De Morgan: !hasWeapon || !hasMana
#     let deMorgan = !hasWeapon || !hasMana;
#
#     // Original: !(isAlive || hasMana)
#     let notEither = !(isAlive || hasMana);
#
#     // De Morgan: !isAlive && !hasMana
#     let deMorgan2 = !isAlive && !hasMana;
#
#     console.log("De Morgan's Laws:");
#     console.log("!(A && B) === (!A || !B):", notBoth === deMorgan);
#     console.log("!(A || B) === (!A && !B):", notEither === deMorgan2);
# }
#
# demonstrateDeMorgan();
#
# // Boolean expressions with optional chaining
# function getWeaponDamage(weaponData, weaponType) {
#     return weaponData?.weapons?.[weaponType]?.damage ?? 10;
# }
#
# let weaponData = {
#     weapons: {
#         sword: { damage: 15, range: 50 },
#         bow: { damage: 10, range: 150 }
#         // No scythe data
#     }
# };
#
# console.log("\nOptional Chaining Boolean Logic:");
# console.log("Sword Damage:", getWeaponDamage(weaponData, "sword"));
# console.log("Scythe Damage (default):", getWeaponDamage(weaponData, "scythe"));
# console.log("Magic Damage (no data):", getWeaponDamage(null, "magic"));
# {% endcapture %}
#
# {% include code-runner.html
#    runner_id="boolean_expressions_exercise"
#    language="javascript"
#    code=code_boolean_expressions
# %}
